# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold

# %%
CP = pd.read_csv('data/CP_data_Mitotox_Mechanisms_658.csv') 
CP
# Out:
#                                 InChICode_standardised  \
# 0    InChI=1S/C32H41NO2/c1-31(2,3)26-18-16-25(17-19...
# 1    InChI=1S/C10H10N2O/c1-8-7-10(13)12(11-8)9-5-3-...
# 2    InChI=1S/C10H10N4O2S/c11-8-2-4-9(5-3-8)17(15,1...
# 3    InChI=1S/C10H11ClO3/c1-10(2,9(12)13)14-8-5-3-7...
# 4    InChI=1S/C10H11N3O3S/c1-7-6-10(12-16-7)13-17(1...
# ..                                                 ...
# 653  InChI=1S/C9H7N7O2S/c1-15-4-14-7(16(17)18)9(15)...
# 654  InChI=1S/C9H9Cl2NO/c1-2-9(13)12-6-3-4-7(10)8(1...
# 655  InChI=1S/C9H9N3O2S2/c10-7-1-3-8(4-2-7)16(13,14...
# 656  InChI=1S/C9H9N3S/c10-12-9-11-8(6-13-9)7-4-2-1-...
# 657  InChI=1S/C9H9NO/c11-6-7-5-10-9-4-2-1-3-8(7)9/h...
#
#      Metadata_mmoles_per_liter  Cells_AreaShape_Area  \
# 0                     5.000000          -2762.925781
# 1                    14.351386             83.085938
# 2                     5.000000           -322.046875
# 3                     5.000000            248.234375
# ...

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
print(scaler.fit(CP.iloc[:, 3:]))
# Out:
# StandardScaler()

# %%
cp_scaled= pd.DataFrame(scaler.transform(CP.iloc[:, 3:]), columns=CP.iloc[:, 3:].columns.to_list())

# %%
file = open("../01_Generate_Ontology/CellPaitningFeatures_overlap.txt", "r")
file_lines = file.read()
CellPaitningFeatures = file_lines.split("\n")
CellPaitningFeatures = CellPaitningFeatures[:-1]

# %%
len(CellPaitningFeatures)
# Out:
# 827

# %%
cp_scaled = cp_scaled[cp_scaled.columns[cp_scaled.columns.isin(CellPaitningFeatures)]]
cp_scaled
# Out:
#      Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                   15.203216                    -2.218845
# 1                   -0.332976                    -0.421052
# 2                    0.044596                    -0.755464
# 3                    0.276479                     0.255746
# 4                   -0.844525                     0.026150
# ..                        ...                          ...
# 653                  0.635782                     0.940464
# 654                 -0.367173                    -0.493951
# 655                 -0.906361                     0.266953
# 656                 -0.326418                    -0.377083
# 657                 -0.406054                     0.466349
#
#      Cells_AreaShape_Eccentricity  Cells_AreaShape_Extent  \
# 0                       -6.231049               -5.054902
# 1                       -0.153210                0.029341
# 2                       -0.532837                0.090075
# ...

# %%
cp_scaled["InChICode_standardised"] = CP["InChICode_standardised"]
cp_scaled
# Out:
# /home/ss2686/miniconda3/envs/my-rdkit-env/lib/python3.9/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
#      Cells_AreaShape_Center_Y  Cells_AreaShape_Compactness  \
# 0                   15.203216                    -2.218845
# 1                   -0.332976                    -0.421052
# 2                    0.044596                    -0.755464
# 3                    0.276479                     0.255746
# 4                   -0.844525                     0.026150
# ..                        ...                          ...
# 653                  0.635782                     0.940464
# 654                 -0.367173                    -0.493951
# ...

# %%
cp_scaled.to_csv("data/CP_data_Mitotox_Mechanisms_658_scaled.csv", index=False)
