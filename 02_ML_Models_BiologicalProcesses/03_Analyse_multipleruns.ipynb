# %%
import pandas as pd

# %%
df1 = pd.read_csv("metrics_df_CP_multiple_runs.csv")
#df1

# %%
df2 = pd.read_csv("metrics_df_Ontology_pvalue_multiple_runs.csv")
#df2

# %%
df3 = pd.read_csv("metrics_df_Ontology_statistic_multiple_runs.csv")
#df3

# %%
metrics_list = pd.concat([df1, df2, df3]).reset_index(drop=True)
#metrics_list

# %%
metrics_list.labels_name.unique()
# Out:
# array(['apoptosis up', 'cytotoxicity BLA', 'cytotoxicity SRB',
#        'ER stress', 'heat shock', 'microtubule up',
#        'mitochondrial disruption up', 'oxidative stress up',
#        'proliferation decrease'], dtype=object)

# %%
metrics_list
# Out:
#                 labels_name                      epoch            Features  \
# 0              apoptosis up             apoptosis up_1         CP_features
# 1              apoptosis up             apoptosis up_2         CP_features
# 2              apoptosis up             apoptosis up_3         CP_features
# 3              apoptosis up             apoptosis up_4         CP_features
# 4              apoptosis up             apoptosis up_5         CP_features
# ..                      ...                        ...                 ...
# 535  proliferation decrease  proliferation decrease_16  Ontology_statistic
# 536  proliferation decrease  proliferation decrease_17  Ontology_statistic
# 537  proliferation decrease  proliferation decrease_18  Ontology_statistic
# 538  proliferation decrease  proliferation decrease_19  Ontology_statistic
# 539  proliferation decrease  proliferation decrease_20  Ontology_statistic
#
#           AUC        ba
# 0    0.631665  0.629731
# ...

# %%
metrics_list.groupby(["labels_name", "Features"]).mean()
# Out:
#                                                      AUC        ba
# labels_name                 Features
# ER stress                   CP_features         0.612440  0.586636
#                             Ontology_pvalue     0.617760  0.583512
#                             Ontology_statistic  0.626706  0.583016
# apoptosis up                CP_features         0.655459  0.631585
#                             Ontology_pvalue     0.646625  0.632641
#                             Ontology_statistic  0.665141  0.633311
# cytotoxicity BLA            CP_features         0.658165  0.613764
#                             Ontology_pvalue     0.655822  0.617564
#                             Ontology_statistic  0.629128  0.601651
# cytotoxicity SRB            CP_features         0.580129  0.573181
#                             Ontology_pvalue     0.582277  0.544385
#                             Ontology_statistic  0.584155  0.543163
# ...

# %%
metrics_list.groupby(["Features"]).mean()
# Out:
#                          AUC        ba
# Features
# CP_features         0.596598  0.574106
# Ontology_pvalue     0.605625  0.571603
# Ontology_statistic  0.585470  0.561416

# %%
metrics_list = metrics_list.replace({'Ontology_pvalue': "Cell Health terms"})
metrics_list = metrics_list.replace({'CP_features': "Cell Painting features"})
metrics_list
# Out:
#                 labels_name                      epoch  \
# 0              apoptosis up             apoptosis up_1
# 1              apoptosis up             apoptosis up_2
# 2              apoptosis up             apoptosis up_3
# 3              apoptosis up             apoptosis up_4
# 4              apoptosis up             apoptosis up_5
# ..                      ...                        ...
# 535  proliferation decrease  proliferation decrease_16
# 536  proliferation decrease  proliferation decrease_17
# 537  proliferation decrease  proliferation decrease_18
# 538  proliferation decrease  proliferation decrease_19
# 539  proliferation decrease  proliferation decrease_20
#
#                    Features       AUC        ba
# 0    Cell Painting features  0.631665  0.629731
# 1    Cell Painting features  0.625560  0.609280
# 2    Cell Painting features  0.654359  0.626667
# 3    Cell Painting features  0.666256  0.633846
# 4    Cell Painting features  0.685999  0.627595
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

pairs = [('Cell Health terms', 'Cell Painting features')]

my_order=['Cell Health terms', 'Cell Painting features']
         

fig, ax = plt.subplots(1, 3,figsize=(20, 4), dpi=300) # sharex='all', sharey='all', 

for i, endpoint in enumerate(['apoptosis up', 'cytotoxicity BLA', 'cytotoxicity SRB']):
    print(i)
    print(endpoint)

    sns.violinplot(ax= ax[i], x="Features", y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order, scale='width', inner='quartile', color="white")
    sns.swarmplot(ax= ax[i],x='Features', y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order,color="grey", alpha=0.8)
    annotator = Annotator(ax[i], pairs, data=metrics_list[metrics_list["labels_name"]==endpoint], x="Features", 
                          y='AUC', order=my_order)
    annotator.configure(test='t-test_paired', text_format='star', loc='outside')
    annotator.apply_and_annotate()
    
plt.show()
# Out:
# 0
# apoptosis up
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:3.463e-01 t=-9.658e-01
# 1
# cytotoxicity BLA
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:7.896e-01 t=-2.706e-01
# 2
# cytotoxicity SRB
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:8.884e-01 t=1.422e-01

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator


         

fig, ax = plt.subplots(1, 3,figsize=(20, 4), dpi=300) # sharex='all', sharey='all', 

for i, endpoint in enumerate(['ER stress', 'heat shock', 'microtubule up']):
    print(i)
    print(endpoint)

    sns.violinplot(ax= ax[i], x="Features", y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order, scale='width', inner='quartile', color="white")
    sns.swarmplot(ax= ax[i],x='Features', y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order,color="grey", alpha=0.8)
    annotator = Annotator(ax[i], pairs, data=metrics_list[metrics_list["labels_name"]==endpoint], x="Features", 
                          y='AUC', order=my_order)
    annotator.configure(test='t-test_paired', text_format='star', loc='outside')
    annotator.apply_and_annotate()
    
plt.show()
# Out:
# 0
# ER stress
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:5.369e-01 t=6.288e-01
# 1
# heat shock
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:2.557e-01 t=1.172e+00
# 2
# microtubule up
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:7.552e-01 t=-3.164e-01

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

         

fig, ax = plt.subplots(1, 3,figsize=(20, 4), dpi=300) # sharex='all', sharey='all', 

for i, endpoint in enumerate(['mitochondrial disruption up', 'oxidative stress up','proliferation decrease']):
    print(i)
    print(endpoint)

    sns.violinplot(ax= ax[i], x="Features", y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order, scale='width', inner='quartile', color="white")
    sns.swarmplot(ax= ax[i],x='Features', y='AUC', data=metrics_list[metrics_list["labels_name"]==endpoint], order=my_order,color="grey", alpha=0.8)
    annotator = Annotator(ax[i], pairs, data=metrics_list[metrics_list["labels_name"]==endpoint], x="Features", 
                          y='AUC', order=my_order)
    annotator.configure(test='t-test_paired', text_format='star', loc='outside')
    annotator.apply_and_annotate()
    
plt.show()
# Out:
# 0
# mitochondrial disruption up
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:6.280e-01 t=-4.924e-01
# 1
# oxidative stress up
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:9.589e-04 t=3.902e+00
# 2
# proliferation decrease
# p-value annotation legend:
#       ns: p <= 1.00e+00
#        *: 1.00e-02 < p <= 5.00e-02
#       **: 1.00e-03 < p <= 1.00e-02
#      ***: 1.00e-04 < p <= 1.00e-03
#     ****: p <= 1.00e-04
#
# Cell Health terms vs. Cell Painting features: t-test paired samples, P_val:1.658e-03 t=3.662e+00
